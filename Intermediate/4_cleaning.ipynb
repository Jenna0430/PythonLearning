# %% [markdown]
# Cleaning

# %%
import pandas as pd
from datasets import load_dataset

# Loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
type(df.job_posted_date[80])
# Out:
# str

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[us]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  str
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
#  15  job_skills             668704 non-null  str
#  16  job_type_skills        668704 non-null  str
# dtypes: bool(3), float64(2), str(12)
# memory usage: 279.3 MB

# %%
df.job_posted_date = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
#  15  job_skills             668704 non-null  str
#  16  job_type_skills        668704 non-null  str
# dtypes: bool(3), datetime64[us](1), float64(2), str(11)
# memory usage: 265.1 MB

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df['job_posted_month'] = df.job_posted_date.dt.month
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
#  15  job_skills             668704 non-null  str
#  16  job_type_skills        668704 non-null  str
#  17  job_posted_month       785741 non-null  int32
# dtypes: bool(3), datetime64[us](1), float64(2), int32(1), str(11)
# memory usage: 268.1 MB

# %%
df.job_posted_month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_month, Length: 785741, dtype: int32

# %%
df.sort_values(by=['job_posted_month'], inplace=True)

# %%
df
# Out:
#           job_title_short                                          job_title  \
# 335487     Data Scientist                                       Data Modeler
# 335486  Software Engineer                        Principal Software Engineer
# 335485      Data Engineer                            Es- Data Engineer Azure
# 39          Data Engineer                                      Data Engineer
# 472238     Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 309117     Data Scientist                                     Data Scientist
# 363983       Data Analyst  Luxury Retail - Regional Data Insight Consulta...
# 139582      Data Engineer                                      Data Engineer
# 139580     Data Scientist                                     Data Scientist
# 335504       Data Analyst                                      Data Analysis
#
#                        job_location                     job_via  \
# 335487            San Francisco, CA                via LinkedIn
# 335486         Edmonton, AB, Canada           via Simplify Jobs
# 335485                Madrid, Spain             via Recruit.net
# 39                   Fort Worth, TX                via LinkedIn
# 472238               Birmingham, AL  via Birmingham, AL - Geebo
# ...                             ...                         ...
# 309117                United States                via LinkedIn
# 363983                    Hong Kong             via Recruit.net
# 139582                      Morocco                via LinkedIn
# 139580  Bengaluru, Karnataka, India             via BeBee India
# 335504                     Thailand          via หางาน | Indeed
#
#        job_schedule_type  job_work_from_home            search_location  \
# 335487        Contractor               False  California, United States
# 335486         Full-time               False                     Canada
# 335485         Full-time               False                      Spain
# 39             Full-time               False       Texas, United States
# 472238         Full-time               False     Florida, United States
# ...                  ...                 ...                        ...
# 309117         Full-time               False       Texas, United States
# 363983        Contractor               False                  Hong Kong
# 139582         Full-time               False                    Morocco
# 139580         Full-time               False                      India
# 335504         Full-time               False                   Thailand
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 335487 2023-01-01 23:01:35                   True                 False
# 335486 2023-01-02 23:30:22                   True                 False
# 335485 2023-01-10 23:41:18                   True                 False
# 39     2023-01-25 13:24:01                  False                 False
# 472238 2023-01-03 23:35:29                  False                  True
# ...                    ...                    ...                   ...
# 309117 2023-12-01 17:02:45                  False                 False
# 363983 2023-12-15 23:37:03                   True                 False
# 139582 2023-12-13 08:22:10                  False                 False
# 139580 2023-12-06 08:08:51                  False                 False
# 335504 2023-12-05 23:22:15                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 335487  United States         NaN              NaN              NaN
# 335486         Canada         NaN              NaN              NaN
# 335485          Spain         NaN              NaN              NaN
# 39      United States         NaN              NaN              NaN
# 472238  United States        hour              NaN             24.0
# ...               ...         ...              ...              ...
# 309117  United States         NaN              NaN              NaN
# 363983      Hong Kong         NaN              NaN              NaN
# 139582        Morocco         NaN              NaN              NaN
# 139580          India         NaN              NaN              NaN
# 335504       Thailand         NaN              NaN              NaN
#
#                             company_name  \
# 335487                     Micasa Global
# 335486                             Clari
# 335485                          Devoteam
# 39                        Programmers.io
# 472238                        Protective
# ...                                  ...
# 309117                Core Digital Media
# 363983  Ambition Group Hong Kong Limited
# 139582                    Groupe Managem
# 139580                    NMS Consultant
# 335504               บริษัท คุ้มสึ จำกัด
#
#                                                job_skills  \
# 335487  ['sql', 'javascript', 'python', 'sas', 'sas', ...
# 335486  ['java', 'mongodb', 'mongodb', 'aws', 'aurora'...
# 335485  ['aws', 'databricks', 'snowflake', 'alteryx', ...
# 39                                      ['sql', 'python']
# 472238  ['r', 'python', 'sas', 'sas', 'sql', 'databric...
# ...                                                   ...
# 309117  ['python', 'sql', 'r', 'sas', 'sas', 'scikit-l...
# 363983                 ['sql', 'r', 'python', 'power bi']
# 139582  ['nosql', 'sql', 'python', 'r', 'javascript', ...
# 139580                 ['r', 'scala', 'python', 'matlab']
# 335504  ['sql', 'python', 'r', 'vba', 'matlab', 'power...
#
#                                           job_type_skills  job_posted_month
# 335487  {'analyst_tools': ['sas', 'excel', 'spss'], 'c...                 1
# 335486  {'cloud': ['aws', 'aurora'], 'databases': ['mo...                 1
# 335485  {'analyst_tools': ['alteryx', 'tableau', 'qlik...                 1
# 39                     {'programming': ['sql', 'python']}                 1
# 472238  {'analyst_tools': ['sas', 'powerpoint'], 'clou...                 1
# ...                                                   ...               ...
# 309117  {'analyst_tools': ['sas', 'power bi'], 'librar...                12
# 363983  {'analyst_tools': ['power bi'], 'programming':...                12
# 139582  {'cloud': ['azure'], 'libraries': ['hadoop'], ...                12
# 139580  {'programming': ['r', 'scala', 'python', 'matl...                12
# 335504  {'analyst_tools': ['power bi', 'excel', 'ms ac...                12
#
# [785741 rows x 18 columns]

# %%
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 785741 entries, 335487 to 335504
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  str
#  14  job_skills             668704 non-null  str
#  15  job_type_skills        668704 non-null  str
#  16  job_posted_month       785741 non-null  int32
# dtypes: bool(3), datetime64[us](1), float64(1), int32(1), str(11)
# memory usage: 268.7 MB

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df
# Out:
#               job_title_short  \
# 335447           Data Analyst
# 785641          Data Engineer
# 156398         Data Scientist
# 785563         Data Scientist
# 575522         Data Scientist
# ...                       ...
# 527097      Software Engineer
# 785395          Data Engineer
# 139434           Data Analyst
# 665161  Senior Data Scientist
# 527579           Data Analyst
#
#                                                 job_title  \
# 335447                Electronic Data Interchange Analyst
# 785641                                      Data Engineer
# 156398           Principal / Sr. Principal Data Scientist
# 785563  Data Scientist I/II (Model Risk Management & M...
# 575522  Scientist  (Computational Nuclear Data Scientist)
# ...                                                   ...
# 527097                                       BI Developer
# 785395  Senior Consultant - Tech Consulting -Azure Dat...
# 139434        Management & Program Analyst (Data Analyst)
# 665161  Senior Credit Strategy Analyst/ Senior Data Sc...
# 527579                                       Data Analyst
#
#                  job_location                                    job_via  \
# 335447               Anywhere                               via LinkedIn
# 785641           New York, NY                                   via Dice
# 156398         Clearfield, UT                                via Ladders
# 785563          Pensacola, FL  via Navy Federal Credit Union - Talentify
# 575522         Los Alamos, NM                                via Ladders
# ...                       ...                                        ...
# 527097     Jakarta, Indonesia                            via Ai-Jobs.net
# 785395                  India                            via Ai-Jobs.net
# 139434          Arlington, VA                           via ZipRecruiter
# 665161             Frisco, TX                               via LinkedIn
# 527579  Elk Grove Village, IL                                  via BeBee
#
#        job_schedule_type  job_work_from_home            search_location  \
# 335447         Full-time                True       Texas, United States
# 785641         Full-time               False                    Georgia
# 156398         Full-time               False  California, United States
# 785563         Full-time               False     Florida, United States
# 575522         Full-time               False                      Sudan
# ...                  ...                 ...                        ...
# 527097         Full-time               False                  Indonesia
# 785395         Full-time               False                      India
# 139434         Full-time               False    New York, United States
# 665161         Full-time               False       Texas, United States
# 527579         Full-time               False    Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 335447 2023-01-18 23:02:57                   True                  True
# 785641 2023-01-04 16:36:07                   True                 False
# 156398 2023-01-19 08:21:50                  False                  True
# 785563 2023-01-11 06:22:10                  False                 False
# 575522 2023-01-31 10:34:22                  False                  True
# ...                    ...                    ...                   ...
# 527097 2023-12-19 11:39:07                  False                 False
# 785395 2023-12-19 06:10:41                  False                 False
# 139434 2023-12-27 08:00:18                   True                 False
# 665161 2023-12-29 10:02:21                  False                  True
# 527579 2023-12-13 11:02:27                  False                 False
#
#           job_country salary_rate  salary_year_avg  \
# 335447  United States        year          65000.0
# 785641  United States        year         150000.0
# 156398  United States        year          90000.0
# 785563  United States        year         136400.0
# 575522          Sudan        year         115000.0
# ...               ...         ...              ...
# 527097      Indonesia        year         123000.0
# 785395          India        year          64800.0
# 139434  United States        year         156000.0
# 665161  United States        year         170000.0
# 527579  United States        year          65000.0
#
#                               company_name  \
# 335447                      Insight Global
# 785641               Engage Partners, Inc.
# 156398                    Northrop Grumman
# 785563           Navy Federal Credit Union
# 575522      Los Alamos National Laboratory
# ...                                    ...
# 527097                            NTT DATA
# 785395                                  EY
# 139434  Office of the Secretary of Defense
# 665161                                SoFi
# 527579                 First American Bank
#
#                                                job_skills  \
# 335447                                          ['excel']
# 785641                                                NaN
# 156398                                            ['sap']
# 785563  ['r', 'python', 'matplotlib', 'ggplot2', 'spar...
# 575522                                  ['c++', 'python']
# ...                                                   ...
# 527097  ['java', 'python', 'sql', 'no-sql', 'mongodb',...
# 785395  ['sql', 'python', 'azure', 'databricks', 'spar...
# 139434                                  ['c', 'terminal']
# 665161              ['sql', 'python', 'excel', 'tableau']
# 527579                                                NaN
#
#                                           job_type_skills  job_posted_month
# 335447                       {'analyst_tools': ['excel']}                 1
# 785641                                                NaN                 1
# 156398                         {'analyst_tools': ['sap']}                 1
# 785563  {'analyst_tools': ['word', 'power bi', 'tablea...                 1
# 575522                 {'programming': ['c++', 'python']}                 1
# ...                                                   ...               ...
# 527097  {'analyst_tools': ['ssis', 'ssrs', 'tableau'],...                12
# 785395  {'analyst_tools': ['power bi', 'tableau', 'qli...                12
# 139434      {'other': ['terminal'], 'programming': ['c']}                12
# 665161  {'analyst_tools': ['excel', 'tableau'], 'progr...                12
# 527579                                                NaN                12
#
# [22003 rows x 17 columns]

# %%
df[df.salary_year_avg == 'NAN']['salary_year_avg']
# Out:
# Series([], Name: salary_year_avg, dtype: float64)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 22003 entries, 335447 to 527579
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  str
#  1   job_title              22003 non-null  str
#  2   job_location           21723 non-null  str
#  3   job_via                22003 non-null  str
#  4   job_schedule_type      21987 non-null  str
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  str
#  7   job_posted_date        22003 non-null  datetime64[us]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  str
#  11  salary_rate            22003 non-null  str
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  str
#  14  job_skills             20170 non-null  str
#  15  job_type_skills        20170 non-null  str
#  16  job_posted_month       22003 non-null  int32
# dtypes: bool(3), datetime64[us](1), float64(1), int32(1), str(11)
# memory usage: 8.1 MB
