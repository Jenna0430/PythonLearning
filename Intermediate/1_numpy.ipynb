# %%
import numpy as np

# %%
job_titles = np.array(["Data Analyst", "AI Engineer", "Data Engineer", "Machine Learning Engineer", "Data Scientist"])

base_salaries = np.array([600_000, 700_000, 800_000, 1_000_000, np.nan])

bonus_rate = np.array([0.5, 0.3, 0.1, 0.2, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rate)
total_salaries
# Out:
# array([ 900000.,  910000.,  880000., 1200000.])

# %%
total_salaries.mean()
# Out:
# np.float64(972500.0)
