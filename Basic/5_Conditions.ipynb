# %% [markdown]
# Conditional Statements

# %%
if True:
    print("Hello")
else:
    print("Sawadee Kap")
# Out:
# Hello

# %%
job_skill = 'SQL'

app_skill = 'SQL'

if job_skill == app_skill:
    print("Skills match")
# Out:
# Skills match

# %%
listOfSkills = ["SQL", "Python", "C++", "R"]

for skill in listOfSkills:
    if skill == app_skill:
        print("Hired")
    else:
        print("Not Hired")
# Out:
# Hired
# Not Hired
# Not Hired
# Not Hired
