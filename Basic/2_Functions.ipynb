# %%
job_title = "Data Analyst"
job_location = "United States"
job_salary = 900000

# %%
def introduction (jt, jl, js, name):
    return f"Hello, I am {name}, a {jt} at {jl} earning {js}"

# %%
introduction(job_title, job_location, job_salary, "Peter")
# Out:
# 'Hello, I am Peter, a Data Analyst at United States earning 900000'

# %%
introduction(job_location, job_title, job_salary, "Peter")
# Out:
# 'Hello, I am Peter, a United States at Data Analyst earning 900000'

# %% [markdown]
# Classes: The Templates of Objects

# %%
class JobPost:
    def __init__(self, title, location, salary): #method 
        self.title = title
        self.location = location
        self.salary = salary

# %%
job_1 = JobPost(job_title, job_location, job_salary)

# %%
job_1.title
# Out:
# 'Data Analyst'

# %%
job_1.salary
# Out:
# 900000

# %%
name = "jenna "
lastName = "Agbor"

# %%
fullName = name + lastName

# %%
fullName
# Out:
# 'jenna Agbor'

# %%
name.capitalize()
# Out:
# 'Jenna '

# %%
job_1.title.replace("a", "o", count=2)
# Out:
# 'Doto Analyst'

# %%
job_1.title.split(sep=" ", maxsplit=1)
# Out:
# ['Data', 'Analyst']
